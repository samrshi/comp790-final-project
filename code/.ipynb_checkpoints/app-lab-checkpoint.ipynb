# %%
import pandas as pd
import altair as alt
import numpy as np

data = pd.read_csv("app-lab-data.csv") # This data is for two semesters (Fall 2021/ Spring 2022)

# Sun 3/31/2024 - the date that room reservations went live!

data.head()
# Out:
#     id            name        date    timeIn   timeOut Duration  \
# 0  360      Charles Ma  2021-09-01  13:01:00  13:10:00  0:09:00
# 1  362  Jonathan Segal  2021-09-01  14:22:00  14:43:00  0:21:00
# 2  361    Miranda Tran  2021-09-01  13:05:00  13:10:00  0:05:00
# 3  363     Peter Close  2021-09-01  14:26:00  15:02:00  0:36:00
# 4  364  Jonathan Segal  2021-09-02  12:30:00  13:41:00  1:11:00
#
#                reason          classification staff comments          PID  \
# 0             working         work/study/hang   NaN      NaN  730401800.0
# 1  checking stuff out                    tour   NaN      NaN  730248182.0
# 2             working         work/study/hang   NaN      NaN  730393052.0
# 3             working         work/study/hang   NaN      NaN  730442455.0
# 4            app work  project/workshop/staff   NaN      NaN  730248182.0
#
#    hasPID  firstTime heard_about_al_through
# 0    True       True                 Friend
# 1    True       True                 Poster
# 2    True       True                 Friend
# 3    True      False                    NaN
# 4    True      False                    NaN

# %%
# pd.set_option('display.max_rows', 500)

data['Duration (hrs)'] = pd.to_timedelta(data['Duration']).dt.total_seconds() / 3600 
# data['name'] = data['name'].str.lower()

# total_time_per_user = data.groupby('PID')['Duration (datetime)'].sum().reset_index()
grouped_by_pid = data.groupby(['name'])
summed = grouped_by_pid['Duration (hrs)'].sum().reset_index()
sorted = summed.sort_values(by='Duration (hrs)', ascending=False)

summed.count()

# Create table for top 10 students in duration of time.  
# total_time_per_user = data.groupby('id')['Duration'].sum().reset_index()

# total_time_per_user['Duration'] = pd.to_timedelta(total_time_per_user['Duration']).dt.total_seconds() / 3600 

# total_time_per_user_sorted = total_time_per_user.sort_values(by='Duration', ascending=False)

# total_time_per_user_sorted.head(10)
# Out:
# name              151
# Duration (hrs)    151
# dtype: int64

# %%
# Visualization of the top users in each space.

chart = alt.Chart(sorted.head(10)).mark_bar().encode(
    y=alt.Y('Name:O', title='User ID', sort="-x"),
    x=alt.X('Duration (hrs)', title='Time (Hours)'),
    tooltip=alt.Tooltip('Duration (hrs)')
).properties(
    title='Total Time per User (Hours)'
)

chart
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/homebrew/lib/python3.12/site-packages/altair/vegalite/v5/api.py in ?(self, include, exclude)
#    2569         # see https://github.com/ipython/ipython/issues/11038
#    2570         try:
#    2571             dct = self.to_dict(context={"pre_transform": False})
#    2572         except Exception:
# -> 2573             utils.display_traceback(in_ipython=True)
#    2574             return {}
#    2575         else:
#    2576             return renderers.get()(dct)
#
# /opt/homebrew/lib/python3.12/site-packages/altair/vegalite/v5/api.py in ?(self, validate, format, ignore, context)
#    2971             copy.data = core.InlineData(values=[{}])  # type: ignore[assignment]
#    2972             return super(Chart, copy).to_dict(
#    2973                 validate=validate, format=format, ignore=ignore, context=context
#    2974             )
# -> 2975         return super().to_dict(
#    2976             validate=validate, format=format, ignore=ignore, context=context
#    2977         )
#
# /opt/homebrew/lib/python3.12/site-packages/altair/vegalite/v5/api.py in ?(self, validate, format, ignore, context)
#     957
#     958         # TopLevelMixin instance does not necessarily have to_dict defined
#     959         # but due to how Altair is set up this should hold.
#     960         # Too complex to type hint right now
# --> 961         vegalite_spec = super(TopLevelMixin, copy).to_dict(  # type: ignore[misc]
#     962             validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#     963         )
#     964
#
# /opt/homebrew/lib/python3.12/site-packages/altair/utils/schemapi.py in ?(self, validate, ignore, context)
#     956                 k: v for k, v in kwds.items() if k not in list(ignore) + ["shorthand"]
#     957             }
#     958             if "mark" in kwds and isinstance(kwds["mark"], str):
#     959                 kwds["mark"] = {"type": kwds["mark"]}
# --> 960             result = _todict(
#     961                 kwds,
#     962                 context=context,
#     963             )
#
# /opt/homebrew/lib/python3.12/site-packages/altair/utils/schemapi.py in ?(obj, context)
#     472         return obj.to_dict(validate=False, context=context)
#     473     elif isinstance(obj, (list, tuple, np.ndarray)):
#     474         return [_todict(v, context) for v in obj]
#     475     elif isinstance(obj, dict):
# --> 476         return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477     elif hasattr(obj, "to_dict"):
#     478         return obj.to_dict()
#     479     elif isinstance(obj, np.number):
#
# /opt/homebrew/lib/python3.12/site-packages/altair/utils/schemapi.py in ?(obj, context)
#     469 def _todict(obj: Any, context: Optional[Dict[str, Any]]) -> Any:
#     470     """Convert an object to a dict representation."""
#     471     if isinstance(obj, SchemaBase):
# --> 472         return obj.to_dict(validate=False, context=context)
#     473     elif isinstance(obj, (list, tuple, np.ndarray)):
#     474         return [_todict(v, context) for v in obj]
#     475     elif isinstance(obj, dict):
#
# /opt/homebrew/lib/python3.12/site-packages/altair/utils/schemapi.py in ?(self, validate, ignore, context)
#     956                 k: v for k, v in kwds.items() if k not in list(ignore) + ["shorthand"]
#     957             }
#     958             if "mark" in kwds and isinstance(kwds["mark"], str):
#     959                 kwds["mark"] = {"type": kwds["mark"]}
# --> 960             result = _todict(
#     961                 kwds,
#     962                 context=context,
#     963             )
#
# /opt/homebrew/lib/python3.12/site-packages/altair/utils/schemapi.py in ?(obj, context)
#     472         return obj.to_dict(validate=False, context=context)
#     473     elif isinstance(obj, (list, tuple, np.ndarray)):
#     474         return [_todict(v, context) for v in obj]
#     475     elif isinstance(obj, dict):
# --> 476         return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477     elif hasattr(obj, "to_dict"):
#     478         return obj.to_dict()
#     479     elif isinstance(obj, np.number):
#
# /opt/homebrew/lib/python3.12/site-packages/altair/utils/schemapi.py in ?(obj, context)
#     469 def _todict(obj: Any, context: Optional[Dict[str, Any]]) -> Any:
#     470     """Convert an object to a dict representation."""
#     471     if isinstance(obj, SchemaBase):
# --> 472         return obj.to_dict(validate=False, context=context)
#     473     elif isinstance(obj, (list, tuple, np.ndarray)):
#     474         return [_todict(v, context) for v in obj]
#     475     elif isinstance(obj, dict):
#
# /opt/homebrew/lib/python3.12/site-packages/altair/vegalite/v5/schema/channels.py in ?(self, validate, ignore, context)
#      60                 # We still parse it out of the shorthand, but drop it here.
#      61                 parsed.pop("type", None)
#      62             elif not (type_in_shorthand or type_defined_explicitly):
#      63                 if isinstance(context.get("data", None), pd.DataFrame):
# ---> 64                     raise ValueError(
#      65                         'Unable to determine data type for the field "{}";'
#      66                         " verify that the field name is not misspelled."
#      67                         " If you are referencing a field from a transform,"
#
# ValueError: Unable to determine data type for the field "Name"; verify that the field name is not misspelled. If you are referencing a field from a transform, also confirm that the data type is specified correctly.
# alt.Chart(...)

# %%
# Do the leaderboard per day. 

# Convert string to TimeDelta Object.
data['date'] = pd.to_datetime(data['date'])

data['timeIn'] = pd.to_timedelta(data['timeIn'])

data['start'] = data['date'] + data['timeIn']

data['day_of_week'] = data['start'].dt.day_name()

data['civilian_time'] = data['start'].dt.strftime("%I %p").str.lstrip("0")

reservations_per_hour = data.groupby(["day_of_week", "civilian_time"]).size().reset_index(name="count")

reservations_per_hour.head(5)
# Out:
#   day_of_week civilian_time  count
# 0      Friday          1 PM     11
# 1      Friday         10 AM      1
# 2      Friday         11 AM      2
# 3      Friday         12 PM     13
# 4      Friday          2 PM     12

# %%
# Load the chart

day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
charts = []
for day in day_order:
    day_data = reservations_per_hour[reservations_per_hour["day_of_week"] == day]

    chart = alt.Chart(day_data).mark_bar().encode( 
        x = alt.X("civilian_time:N", title="Hour of Day", sort=['10 AM', '11 AM', '12 PM', '1 PM', '2 PM', '3 PM', '4 PM', '5 PM']),
        y = alt.Y("count:Q", title=None),
        tooltip = ["count:Q"]
    ).properties(
        title=f'{day}',
        height=150
    )

    charts.append(chart)

final_chart = alt.hconcat(*charts)

final_chart
# Out:
# alt.HConcatChart(...)
